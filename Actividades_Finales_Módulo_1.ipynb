# %% [markdown]
# <a href="https://colab.research.google.com/github/darthfelipe21/Data_Scientist/blob/main/Actividades_Finales_M%C3%B3dulo_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ACTIVIDADES FINALES MÓDULO 1

# %% [markdown]
# Para hacer estas actividades finales usaremos un Dataset que contiene las notas en examenes y homework de un grupo de alumnos. Usa la siguiente url en la función de pandas pd.read_csv para obtener el dataframe: https://raw.githubusercontent.com/realpython/materials/master/pandas-gradebook-project/data/hw_exam_grades.csv

# %% [markdown]
# 1. Importa la librería de Pandas

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# 2. Importa el dataframe de la url mencionada en la introducción y guárdalo en una variable llamada df

# %%
url= 'https://raw.githubusercontent.com/realpython/materials/master/pandas-gradebook-project/data/hw_exam_grades.csv'
prueba= pd.read_csv(url)
df= pd.DataFrame(prueba)

# %% [markdown]
# 3. Aplica la función head para ver las primeras líneas de nuestro dataframe

# %%
df.head()
# Out:
#   First Name  Last Name       SID  Homework 1  Homework 1 - Max Points  \
# 0      Aaron     Lester  axl60952        68.0                       80
# 1       Adam     Cooper  amc28428        80.0                       80
# 2       Alec      Curry  axc64717        69.0                       80
# 3  Alexander  Rodriguez  akr14831        50.0                       80
# 4      Amber    Daniels  axd11293        54.0                       80
#
#   Homework 1 - Submission Time  Homework 2  Homework 2 - Max Points  \
# 0    2019-08-29 08:56:02-07:00          74                       80
# 1    2019-08-29 08:56:02-07:00          78                       80
# 2    2019-08-29 08:56:02-07:00          76                       80
# 3    2019-08-29 08:56:02-07:00          54                       80
# 4    2019-08-29 08:56:02-07:00          57                       80
#
#   Homework 2 - Submission Time  Homework 3  ...  \
# 0    2019-09-05 08:56:02-07:00          77  ...
# 1    2019-09-05 08:56:02-07:00          78  ...
# 2    2019-09-05 08:56:02-07:00          66  ...
# 3    2019-09-05 08:56:02-07:00          74  ...
# 4    2019-09-05 08:56:02-07:00          77  ...
#
#    Homework 10 - Submission Time Exam 1  Exam 1 - Max Points  \
# 0      2019-10-31 08:56:02-07:00     79                  100
# 1      2019-10-31 08:56:02-07:00     65                  100
# 2      2019-10-31 08:56:02-07:00     65                  100
# 3      2019-10-31 08:56:02-07:00     97                  100
# 4      2019-10-31 08:56:02-07:00     68                  100
#
#     Exam 1 - Submission Time Exam 2  Exam 2 - Max Points  \
# 0  2019-10-08 12:30:07-07:00     63                  100
# 1  2019-10-08 12:30:07-07:00     63                  100
# 2  2019-10-08 12:30:07-07:00     78                  100
# 3  2019-10-08 12:30:07-07:00     97                  100
# 4  2019-10-08 12:30:07-07:00     95                  100
#
#     Exam 2 - Submission Time Exam 3  Exam 3 - Max Points  \
# 0  2019-11-08 12:30:07-07:00     68                  100
# 1  2019-11-08 12:30:07-07:00     90                  100
# 2  2019-11-08 12:30:07-07:00     83                  100
# 3  2019-11-08 12:30:07-07:00     81                  100
# 4  2019-11-08 12:30:07-07:00     88                  100
#
#     Exam 3 - Submission Time
# 0  2019-12-08 12:30:07-07:00
# 1  2019-12-08 12:30:07-07:00
# 2  2019-12-08 12:30:07-07:00
# 3  2019-12-08 12:30:07-07:00
# 4  2019-12-08 12:30:07-07:00
#
# [5 rows x 42 columns]

# %% [markdown]
# 4. Trabajaremos solo con algunas de las columnas de df. Crea un dataframe llamado gradebook que contenga las siguientes columnas de df: First Name, Last Name, SID, Homework 1, Homework 2, Homework 3, Exam 1, Exam 2
#
# Aplica la función .head() a gradebook para verificar que esté correcto

# %%
gradebook= df[['First Name', 'Last Name', 'SID', 'Homework 1', 'Homework 2', 'Homework 3', 'Exam 1', 'Exam 2', 'Exam 3']]

gradebook.head()
# Out:
#   First Name  Last Name       SID  Homework 1  Homework 2  Homework 3  Exam 1  \
# 0      Aaron     Lester  axl60952        68.0          74          77      79
# 1       Adam     Cooper  amc28428        80.0          78          78      65
# 2       Alec      Curry  axc64717        69.0          76          66      65
# 3  Alexander  Rodriguez  akr14831        50.0          54          74      97
# 4      Amber    Daniels  axd11293        54.0          57          77      68
#
#    Exam 2  Exam 3
# 0      63      68
# 1      63      90
# 2      78      83
# 3      97      81
# 4      95      88

# %% [markdown]
# A partir de ahora, a no ser que se especificara la contrario, trabajaremos siempre con el dataframe gradebook.

# %% [markdown]
# 5. Encuentra cuántas filas y columnas tiene gradebook mediante la función shape

# %%
gradebook.shape
# Out:
# (150, 9)

# %% [markdown]
# 6. Obtén la información básica del dataframe mediante la función info. Fíjate en si hay alguna columna con elementos nulos y de que tipo son los datos de cada columna.

# %%
gradebook.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 9 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   First Name  150 non-null    object
#  1   Last Name   150 non-null    object
#  2   SID         150 non-null    object
#  3   Homework 1  149 non-null    float64
#  4   Homework 2  150 non-null    int64
#  5   Homework 3  150 non-null    int64
#  6   Exam 1      150 non-null    int64
#  7   Exam 2      150 non-null    int64
#  8   Exam 3      150 non-null    int64
# dtypes: float64(1), int64(5), object(3)
# memory usage: 10.7+ KB

# %% [markdown]
# 7. Vamos a limpiar los nombres de las columnas: pon todos los nombres en minúsculas y que no contengan espacios.

# %%
gradebook.columns= gradebook.columns.str.lower().str.replace(' ','_')

# %% [markdown]
# 8. Aplica la función drop_duplicates a gradebook para eliminar duplicados si los hay, luego imprime la shape del nuevo dataframe y mira si se han borrado registros. Recuerda especificar el parámetro que hace que los cambios se lleven a cabo en el mismo dataframe. ¿Había duplicados?

# %%
gradebook.drop_duplicates(inplace=True)

gradebook.shape
# Out:
# <ipython-input-39-97f95f46495b>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   gradebook.drop_duplicates(inplace=True)
# (150, 9)

# %% [markdown]
# 9. Mira que columnas de gradebook tienen nulos y cuántos registros nulos tienen mediante la función isnull

# %%
gradebook.isnull().sum()
# Out:
# first_name    0
# last_name     0
# sid           0
# homework_1    1
# homework_2    0
# homework_3    0
# exam_1        0
# exam_2        0
# exam_3        0
# dtype: int64

# %% [markdown]
# 10. En el caso de que haya algun valor nulo en la nota de algun examen o homework, reemplaza este nulo que sería un no entregado por un 0. Comprueba que lo has hecho bien volviendo a mirar los nulos de gradebook.

# %%
gradebook['homework_1'].fillna(0, inplace=True)

print(gradebook.isnull().sum())

#Si se ejecuto todo para su corrección, podria existir un valor nulo en la columna 'homework1_s10', el cual es corregido mas adelante

df.columns = df.columns.str.lower().str.replace(' ', '_')

df.columns
# Out:
# first_name    0
# last_name     0
# sid           0
# homework_1    0
# homework_2    0
# homework_3    0
# exam_1        0
# exam_2        0
# exam_3        0
# dtype: int64
# <ipython-input-41-dbdb6901f410>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   gradebook['homework_1'].fillna(0, inplace=True)
# Index(['first_name', 'last_name', 'sid', 'homework_1',
#        'homework_1_-_max_points', 'homework_1_-_submission_time', 'homework_2',
#        'homework_2_-_max_points', 'homework_2_-_submission_time', 'homework_3',
#        'homework_3_-_max_points', 'homework_3_-_submission_time', 'homework_4',
#        'homework_4_-_max_points', 'homework_4_-_submission_time', 'homework_5',
#        'homework_5_-_max_points', 'homework_5_-_submission_time', 'homework_6',
#        'homework_6_-_max_points', 'homework_6_-_submission_time', 'homework_7',
#        'homework_7_-_max_points', 'homework_7_-_submission_time', 'homework_8',
#        'homework_8_-_max_points', 'homework_8_-_submission_time', 'homework_9',
#        'homework_9_-_max_points', 'homework_9_-_submission_time',
#        'homework_10', 'homework_10_-_max_points',
#        'homework_10_-_submission_time', 'exam_1', 'exam_1_-_max_points',
#        'exam_1_-_submission_time', 'exam_2', 'exam_2_-_max_points',
#        'exam_2_-_submission_time', 'exam_3', 'exam_3_-_max_points',
#        'exam_3_-_submission_time'],
#       dtype='object')

# %% [markdown]
# 11. En nuestro dataframe, para cada tarea tenemos una columna con la nota que sacó el alumno y otra columna que nos indica el máximo de puntuación que se podía sacar en esa tarea.
#
# Hagamos que todas las notas estén sobre 10. Para ello crea una función que dada una nota y el máximo que se podia sacar en esa tarea, divida la nota entre el máximo y lo multiplique por 10 para sacar la nota sobre 10.
#
# Luego, aplica esta función a cada una de las tareas y guarda la nota obtenida para cada tarea en una columna llamada nombretarea_s10. Por ejemplo homework1_s10 o exam1_s10.

# %%
def add_columns(dafra):
    for i in range(1, 11):
        dafra[f'homework{i}_s10'] = round((df[f'homework_{i}']/df[f'homework_{i}_-_max_points'])*10, 1)
  
    return dafra

add_columns(gradebook)

def add_columns_2(dafra2):
    for i in range(1, 4):
        dafra2[f'exam{i}_s10'] = round((df[f'exam_{i}']/df[f'exam_{i}_-_max_points'])*10, 1)
  
    return dafra2

add_columns_2(gradebook)

gradebook['homework1_s10'].fillna(0, inplace=True)

gradebook
# Out:
# <ipython-input-42-b76764384fd1>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dafra[f'homework{i}_s10'] = round((df[f'homework_{i}']/df[f'homework_{i}_-_max_points'])*10, 1)
# <ipython-input-42-b76764384fd1>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dafra[f'homework{i}_s10'] = round((df[f'homework_{i}']/df[f'homework_{i}_-_max_points'])*10, 1)
# <ipython-input-42-b76764384fd1>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dafra[f'homework{i}_s10'] = round((df[f'homework_{i}']/df[f'homework_{i}_-_max_points'])*10, 1)
# <ipython-input-42-b76764384fd1>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dafra[f'homework{i}_s10'] = round((df[f'homework_{i}']/df[f'homework_{i}_-_max_points'])*10, 1)
# <ipython-input-42-b76764384fd1>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dafra[f'homework{i}_s10'] = round((df[f'homework_{i}']/df[f'homework_{i}_-_max_points'])*10, 1)
# <ipython-input-42-b76764384fd1>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dafra[f'homework{i}_s10'] = round((df[f'homework_{i}']/df[f'homework_{i}_-_max_points'])*10, 1)
# <ipython-input-42-b76764384fd1>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dafra[f'homework{i}_s10'] = round((df[f'homework_{i}']/df[f'homework_{i}_-_max_points'])*10, 1)
# <ipython-input-42-b76764384fd1>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dafra[f'homework{i}_s10'] = round((df[f'homework_{i}']/df[f'homework_{i}_-_max_points'])*10, 1)
# <ipython-input-42-b76764384fd1>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dafra[f'homework{i}_s10'] = round((df[f'homework_{i}']/df[f'homework_{i}_-_max_points'])*10, 1)
# <ipython-input-42-b76764384fd1>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dafra[f'homework{i}_s10'] = round((df[f'homework_{i}']/df[f'homework_{i}_-_max_points'])*10, 1)
# <ipython-input-42-b76764384fd1>:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dafra2[f'exam{i}_s10'] = round((df[f'exam_{i}']/df[f'exam_{i}_-_max_points'])*10, 1)
# <ipython-input-42-b76764384fd1>:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dafra2[f'exam{i}_s10'] = round((df[f'exam_{i}']/df[f'exam_{i}_-_max_points'])*10, 1)
# <ipython-input-42-b76764384fd1>:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dafra2[f'exam{i}_s10'] = round((df[f'exam_{i}']/df[f'exam_{i}_-_max_points'])*10, 1)
# <ipython-input-42-b76764384fd1>:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   gradebook['homework1_s10'].fillna(0, inplace=True)
#     first_name   last_name       sid  homework_1  homework_2  homework_3  \
# 0        Aaron      Lester  axl60952        68.0          74          77
# 1         Adam      Cooper  amc28428        80.0          78          78
# 2         Alec       Curry  axc64717        69.0          76          66
# 3    Alexander   Rodriguez  akr14831        50.0          54          74
# 4        Amber     Daniels  axd11293        54.0          57          77
# ..         ...         ...       ...         ...         ...         ...
# 145     Travis  Washington  txw75701        64.0          67          56
# 146       Troy     Raymond  tbr17292        50.0          59          79
# 147   Victoria        Boyd  vkb66346        58.0          61          75
# 148    William      Daniel  wad63934        48.0          60          72
# 149      Woody     Barrera  wxb12345        55.0          62          73
#
#      exam_1  exam_2  exam_3  homework1_s10  ...  homework4_s10  homework5_s10  \
# 0        79      63      68            8.5  ...            8.9            7.3
# 1        65      63      90           10.0  ...            8.7            9.3
# 2        65      78      83            8.6  ...            8.7            8.4
# 3        97      97      81            6.2  ...            7.5            7.7
# 4        68      95      88            6.8  ...            9.5            6.7
# ..      ...     ...     ...            ...  ...            ...            ...
# 145      94      74      68            8.0  ...            9.2            7.1
# 146      91      67     100            6.2  ...            9.8            9.3
# 147      68      93      69            7.2  ...            9.9            7.4
# 148      84      91      95            6.0  ...            7.6            9.3
# 149      86      62      90            6.9  ...            8.3            9.7
#
#      homework6_s10  homework7_s10  homework8_s10  homework9_s10  \
# 0              9.7            6.6            6.9            7.0
# 1              6.1            8.8            6.3            7.5
# 2              9.2            8.6            9.3            9.7
# 3              6.6            7.6            6.1            6.3
# 4              9.7            8.8            8.3            7.7
# ..             ...            ...            ...            ...
# 145            9.4            9.2            9.9            6.7
# 146            7.6            8.8            9.4            7.5
# 147            9.6            6.8            7.3            6.7
# 148            6.7            7.6            8.9            8.5
# 149            9.7            7.2            6.1            7.5
#
#      homework10_s10  exam1_s10  exam2_s10  exam3_s10
# 0               6.8        7.9        6.3        6.8
# 1               8.8        6.5        6.3        9.0
# 2               7.0        6.5        7.8        8.3
# 3               7.8        9.7        9.7        8.1
# 4               9.8        6.8        9.5        8.8
# ..              ...        ...        ...        ...
# 145             8.7        9.4        7.4        6.8
# 146             8.2        9.1        6.7       10.0
# 147             8.3        6.8        9.3        6.9
# 148             6.0        8.4        9.1        9.5
# 149             7.7        8.6        6.2        9.0
#
# [150 rows x 22 columns]

# %% [markdown]
# Usa las columnas con las notas calculadas sobre 10 para responder las preguntas siguientes:

# %% [markdown]
# 12. Cuántos alumnos han sacado menos de un 7 en el Homework3?

# %%
print((gradebook['homework3_s10'] < 7).sum())
# Out:
# 39

# %% [markdown]
# 13. Cuántos alumnos sacaron un 10 sobre 10 en el examen 1? Y cuál es la media del examen 2, de los alumnos que sacaron un 10 en el examen 1?

# %%
print((gradebook['exam1_s10'] == 10).sum())

#alumnos que sacaron 10 en el examen 1

filter_examen_1=gradebook[gradebook['exam1_s10']==10]
np.mean(filter_examen_1['exam2_s10'])
# Out:
# 4
# 7.625

# %% [markdown]
# 14. Crea una columna que contenga la media de las 3 homeworks para cada alumno y llamala homework_mean y otra que contenga la media de los 2 examenes para cada alumno y llamala exam_mean. Recuerda que la media se calcula como la suma de los elementos entre el número de elementos

# %%
gradebook['homework_mean']= round((gradebook['homework_1'] + gradebook['homework_2'] + gradebook['homework_3'])/3, 2)

gradebook['exam_mean']= round((gradebook['exam_1'] + gradebook['exam_2'] + gradebook['exam_3'])/3, 2)

gradebook
# Out:
# <ipython-input-45-7c17e62a6a7f>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   gradebook['homework_mean']= round((gradebook['homework_1'] + gradebook['homework_2'] + gradebook['homework_3'])/3, 2)
# <ipython-input-45-7c17e62a6a7f>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   gradebook['exam_mean']= round((gradebook['exam_1'] + gradebook['exam_2'] + gradebook['exam_3'])/3, 2)
#     first_name   last_name       sid  homework_1  homework_2  homework_3  \
# 0        Aaron      Lester  axl60952        68.0          74          77
# 1         Adam      Cooper  amc28428        80.0          78          78
# 2         Alec       Curry  axc64717        69.0          76          66
# 3    Alexander   Rodriguez  akr14831        50.0          54          74
# 4        Amber     Daniels  axd11293        54.0          57          77
# ..         ...         ...       ...         ...         ...         ...
# 145     Travis  Washington  txw75701        64.0          67          56
# 146       Troy     Raymond  tbr17292        50.0          59          79
# 147   Victoria        Boyd  vkb66346        58.0          61          75
# 148    William      Daniel  wad63934        48.0          60          72
# 149      Woody     Barrera  wxb12345        55.0          62          73
#
#      exam_1  exam_2  exam_3  homework1_s10  ...  homework6_s10  homework7_s10  \
# 0        79      63      68            8.5  ...            9.7            6.6
# 1        65      63      90           10.0  ...            6.1            8.8
# 2        65      78      83            8.6  ...            9.2            8.6
# 3        97      97      81            6.2  ...            6.6            7.6
# 4        68      95      88            6.8  ...            9.7            8.8
# ..      ...     ...     ...            ...  ...            ...            ...
# 145      94      74      68            8.0  ...            9.4            9.2
# 146      91      67     100            6.2  ...            7.6            8.8
# 147      68      93      69            7.2  ...            9.6            6.8
# 148      84      91      95            6.0  ...            6.7            7.6
# 149      86      62      90            6.9  ...            9.7            7.2
#
#      homework8_s10  homework9_s10  homework10_s10  exam1_s10  exam2_s10  \
# 0              6.9            7.0             6.8        7.9        6.3
# 1              6.3            7.5             8.8        6.5        6.3
# 2              9.3            9.7             7.0        6.5        7.8
# 3              6.1            6.3             7.8        9.7        9.7
# 4              8.3            7.7             9.8        6.8        9.5
# ..             ...            ...             ...        ...        ...
# 145            9.9            6.7             8.7        9.4        7.4
# 146            9.4            7.5             8.2        9.1        6.7
# 147            7.3            6.7             8.3        6.8        9.3
# 148            8.9            8.5             6.0        8.4        9.1
# 149            6.1            7.5             7.7        8.6        6.2
#
#      exam3_s10  homework_mean  exam_mean
# 0          6.8          73.00      70.00
# 1          9.0          78.67      72.67
# 2          8.3          70.33      75.33
# 3          8.1          59.33      91.67
# 4          8.8          62.67      83.67
# ..         ...            ...        ...
# 145        6.8          62.33      78.67
# 146       10.0          62.67      86.00
# 147        6.9          64.67      76.67
# 148        9.5          60.00      90.00
# 149        9.0          63.33      79.33
#
# [150 rows x 24 columns]

# %% [markdown]
# 15. Haz un scatter plot que relacione homework_mean con examen_mean, ves alguna relacion interesante?
# Recuerda importar la libreria matplotlib.pyplot

# %%
plt.scatter(x= gradebook['homework_mean'], y= gradebook['exam_mean'], marker= 'x', c= 'red')
plt.title('Relación entre la media de tareas y examenes')
plt.xlabel('Media de las tareas 1, 2 y 3')
plt.ylabel('Media de los examenes')
plt.show()

#No existe una relación relevante entre estas 2 medias, ya que existe una dispersión significativa, como se puede apreciar en el gráfico
